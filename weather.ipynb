# %% [markdown]
# <a href="https://colab.research.google.com/github/ManasaRongala/ManasaRongala/blob/main/DATA_ANALYSIS_ON_WEATHER_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **WEATHER PREDICTION.**

# %% [markdown]
# Weather Data set is a time-series with per hour information about the weather conditions at a particular location .It records Temperature,Dew point temperature.relative humidity,wind speed,visibility,pressure,and conditions.

# %%
import pandas as pd

# %%
data = pd.read_csv(r"/content/1. Weather Data.csv")

# %%
data
# Out:
#              Date/Time  Temp_C  ...  Press_kPa               Weather
# 0        1/1/2012 0:00    -1.8  ...     101.24                   Fog
# 1        1/1/2012 1:00    -1.8  ...     101.24                   Fog
# 2        1/1/2012 2:00    -1.8  ...     101.26  Freezing Drizzle,Fog
# 3        1/1/2012 3:00    -1.5  ...     101.27  Freezing Drizzle,Fog
# 4        1/1/2012 4:00    -1.5  ...     101.23                   Fog
# ...                ...     ...  ...        ...                   ...
# 8779  12/31/2012 19:00     0.1  ...     100.13                  Snow
# 8780  12/31/2012 20:00     0.2  ...     100.03                  Snow
# 8781  12/31/2012 21:00    -0.5  ...      99.95                  Snow
# 8782  12/31/2012 22:00    -0.2  ...      99.91                  Snow
# 8783  12/31/2012 23:00     0.0  ...      99.89                  Snow
#
# [8784 rows x 8 columns]

# %% [markdown]
# #HOW TO ANALYZE DATA FRAMES?

# %% [markdown]
# #.head

# %% [markdown]
# It shows the first N rows in the data(by default N = 5)

# %%
data.head()
# Out:
#        Date/Time  Temp_C  ...  Press_kPa               Weather
# 0  1/1/2012 0:00    -1.8  ...     101.24                   Fog
# 1  1/1/2012 1:00    -1.8  ...     101.24                   Fog
# 2  1/1/2012 2:00    -1.8  ...     101.26  Freezing Drizzle,Fog
# 3  1/1/2012 3:00    -1.5  ...     101.27  Freezing Drizzle,Fog
# 4  1/1/2012 4:00    -1.5  ...     101.23                   Fog
#
# [5 rows x 8 columns]

# %% [markdown]
# #.shape

# %% [markdown]
# It shows the total no of rows and columns in the data

# %%
data.shape
# Out:
# (8784, 8)

# %% [markdown]
# #.index

# %% [markdown]
#  **The atributes provides the index of the dataframe.**

# %%
data.index
# Out:
# RangeIndex(start=0, stop=8784, step=1)

# %% [markdown]
# #.columns

# %% [markdown]
# **It shows the name of each column**

# %%
data.columns
# Out:
# Index(['Date/Time', 'Temp_C', 'Dew Point Temp_C', 'Rel Hum_%',
#        'Wind Speed_km/h', 'Visibility_km', 'Press_kPa', 'Weather'],
#       dtype='object')

# %% [markdown]
# #.dtypes

# %% [markdown]
# **It shows the datatype of each column.**

# %%
data.dtypes
# Out:
# Date/Time            object
# Temp_C              float64
# Dew Point Temp_C    float64
# Rel Hum_%             int64
# Wind Speed_km/h       int64
# Visibility_km       float64
# Press_kPa           float64
# Weather              object
# dtype: object

# %% [markdown]
# #.unique

# %% [markdown]
# **In a column,it shows all the unique values.It can be applied on a single column only.not on the whole dataframe.**

# %%
data['Weather'].unique()
# Out:
# array(['Fog', 'Freezing Drizzle,Fog', 'Mostly Cloudy', 'Cloudy', 'Rain',
#        'Rain Showers', 'Mainly Clear', 'Snow Showers', 'Snow', 'Clear',
#        'Freezing Rain,Fog', 'Freezing Rain', 'Freezing Drizzle',
#        'Rain,Snow', 'Moderate Snow', 'Freezing Drizzle,Snow',
#        'Freezing Rain,Snow Grains', 'Snow,Blowing Snow', 'Freezing Fog',
#        'Haze', 'Rain,Fog', 'Drizzle,Fog', 'Drizzle',
#        'Freezing Drizzle,Haze', 'Freezing Rain,Haze', 'Snow,Haze',
#        'Snow,Fog', 'Snow,Ice Pellets', 'Rain,Haze', 'Thunderstorms,Rain',
#        'Thunderstorms,Rain Showers', 'Thunderstorms,Heavy Rain Showers',
#        'Thunderstorms,Rain Showers,Fog', 'Thunderstorms',
#        'Thunderstorms,Rain,Fog',
#        'Thunderstorms,Moderate Rain Showers,Fog', 'Rain Showers,Fog',
#        'Rain Showers,Snow Showers', 'Snow Pellets', 'Rain,Snow,Fog',
#        'Moderate Rain,Fog', 'Freezing Rain,Ice Pellets,Fog',
# ...

# %% [markdown]
# #.nuninque()

# %% [markdown]
# **It shows the total no of unique values in each column.It can be applied on a single column as well as on whole dataframe.**

# %%
data.nunique()
# Out:
# Date/Time           8784
# Temp_C               533
# Dew Point Temp_C     489
# Rel Hum_%             83
# Wind Speed_km/h       34
# Visibility_km         24
# Press_kPa            518
# Weather               50
# dtype: int64

# %% [markdown]
# #.count

# %% [markdown]
# **It shows the total non-null values in each column.It can be applied on a single column as well as whole dataframe**

# %%
data.count()
# Out:
# Date/Time           8784
# Temp_C              8784
# Dew Point Temp_C    8784
# Rel Hum_%           8784
# Wind Speed_km/h     8784
# Visibility_km       8784
# Press_kPa           8784
# Weather             8784
# dtype: int64

# %% [markdown]
# #.value_counts

# %% [markdown]
# **In a column,it shows all the unique values with the count.It can be applied on single column only.**

# %%
data['Weather'].value_counts()
# Out:
# Mainly Clear                               2106
# Mostly Cloudy                              2069
# Cloudy                                     1728
# Clear                                      1326
# Snow                                        390
# Rain                                        306
# Rain Showers                                188
# Fog                                         150
# Rain,Fog                                    116
# Drizzle,Fog                                  80
# Snow Showers                                 60
# Drizzle                                      41
# Snow,Fog                                     37
# Snow,Blowing Snow                            19
# Rain,Snow                                    18
# Thunderstorms,Rain Showers                   16
# Haze                                         16
# Drizzle,Snow,Fog                             15
# Freezing Rain                                14
# Freezing Drizzle,Snow                        11
# ...

# %% [markdown]
# #.info

# %% [markdown]
# **Provides basic information about the dataframe.**

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8784 entries, 0 to 8783
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date/Time         8784 non-null   object
#  1   Temp_C            8784 non-null   float64
#  2   Dew Point Temp_C  8784 non-null   float64
#  3   Rel Hum_%         8784 non-null   int64
#  4   Wind Speed_km/h   8784 non-null   int64
#  5   Visibility_km     8784 non-null   float64
#  6   Press_kPa         8784 non-null   float64
#  7   Weather           8784 non-null   object
# dtypes: float64(4), int64(2), object(2)
# memory usage: 549.1+ KB

# %% [markdown]
# **FIND ALL THE UNIQUE 'Wind Speed'values in the data**

# %%
data.head(2)
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  ...  Visibility_km  Press_kPa  Weather
# 0  1/1/2012 0:00    -1.8              -3.9  ...            8.0     101.24      Fog
# 1  1/1/2012 1:00    -1.8              -3.7  ...            8.0     101.24      Fog
#
# [2 rows x 8 columns]

# %%
data.nunique()
# Out:
# Date/Time           8784
# Temp_C               533
# Dew Point Temp_C     489
# Rel Hum_%             83
# Wind Speed_km/h       34
# Visibility_km         24
# Press_kPa            518
# Weather               50
# dtype: int64

# %%
data['Wind Speed_km/h'].nunique()
# Out:
# 34

# %%
data['Wind Speed_km/h'].unique()
# Out:
# array([ 4,  7,  6,  9, 15, 13, 20, 22, 19, 24, 30, 35, 39, 32, 33, 26, 44,
#        43, 48, 37, 28, 17, 11,  0, 83, 70, 57, 46, 41, 52, 50, 63, 54,  2])

# %% [markdown]
# **Find the number of times when the "Weather is exactly Cleat".**

# %%
data.head(2)
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  ...  Visibility_km  Press_kPa  Weather
# 0  1/1/2012 0:00    -1.8              -3.9  ...            8.0     101.24      Fog
# 1  1/1/2012 1:00    -1.8              -3.7  ...            8.0     101.24      Fog
#
# [2 rows x 8 columns]

# %%
#value_counts()
data.Weather.value_counts()
# Out:
# Mainly Clear                               2106
# Mostly Cloudy                              2069
# Cloudy                                     1728
# Clear                                      1326
# Snow                                        390
# Rain                                        306
# Rain Showers                                188
# Fog                                         150
# Rain,Fog                                    116
# Drizzle,Fog                                  80
# Snow Showers                                 60
# Drizzle                                      41
# Snow,Fog                                     37
# Snow,Blowing Snow                            19
# Rain,Snow                                    18
# Thunderstorms,Rain Showers                   16
# Haze                                         16
# Drizzle,Snow,Fog                             15
# Freezing Rain                                14
# Freezing Drizzle,Snow                        11
# ...

# %%
#filtering
data.head(2)
data[data.Weather == 'Clear']
# Out:
#              Date/Time  Temp_C  ...  Press_kPa  Weather
# 67      1/3/2012 19:00   -16.9  ...     101.74    Clear
# 114     1/5/2012 18:00    -7.1  ...     100.71    Clear
# 115     1/5/2012 19:00    -9.2  ...     100.80    Clear
# 116     1/5/2012 20:00    -9.8  ...     100.83    Clear
# 117     1/5/2012 21:00    -9.0  ...     100.83    Clear
# ...                ...     ...  ...        ...      ...
# 8646   12/26/2012 6:00   -13.4  ...     102.47    Clear
# 8698  12/28/2012 10:00    -6.1  ...     101.27    Clear
# 8713   12/29/2012 1:00   -11.9  ...     101.31    Clear
# 8714   12/29/2012 2:00   -11.8  ...     101.33    Clear
# 8756  12/30/2012 20:00   -13.8  ...     101.52    Clear
#
# [1326 rows x 8 columns]

# %%
#groupby()
#data.head(2)
data.groupby('Weather').get_group('Clear')
# Out:
#              Date/Time  Temp_C  ...  Press_kPa  Weather
# 67      1/3/2012 19:00   -16.9  ...     101.74    Clear
# 114     1/5/2012 18:00    -7.1  ...     100.71    Clear
# 115     1/5/2012 19:00    -9.2  ...     100.80    Clear
# 116     1/5/2012 20:00    -9.8  ...     100.83    Clear
# 117     1/5/2012 21:00    -9.0  ...     100.83    Clear
# ...                ...     ...  ...        ...      ...
# 8646   12/26/2012 6:00   -13.4  ...     102.47    Clear
# 8698  12/28/2012 10:00    -6.1  ...     101.27    Clear
# 8713   12/29/2012 1:00   -11.9  ...     101.31    Clear
# 8714   12/29/2012 2:00   -11.8  ...     101.33    Clear
# 8756  12/30/2012 20:00   -13.8  ...     101.52    Clear
#
# [1326 rows x 8 columns]

# %% [markdown]
# **FIND THE NUMBER OF TIMES WHEN THE 'WIND SPEED WAS EXACTLY 4 Km/h'.**

# %%
data.head(2)
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  ...  Visibility_km  Press_kPa  Weather
# 0  1/1/2012 0:00    -1.8              -3.9  ...            8.0     101.24      Fog
# 1  1/1/2012 1:00    -1.8              -3.7  ...            8.0     101.24      Fog
#
# [2 rows x 8 columns]

# %%
data[data['Wind Speed_km/h'] == 4] #Answer
# Out:
#              Date/Time  Temp_C  ...  Press_kPa       Weather
# 0        1/1/2012 0:00    -1.8  ...     101.24           Fog
# 1        1/1/2012 1:00    -1.8  ...     101.24           Fog
# 96       1/5/2012 0:00    -8.8  ...     100.32          Snow
# 101      1/5/2012 5:00    -7.0  ...     100.19          Snow
# 146      1/7/2012 2:00    -8.1  ...     100.15        Cloudy
# ...                ...     ...  ...        ...           ...
# 8768   12/31/2012 8:00    -8.6  ...     101.14  Snow Showers
# 8769   12/31/2012 9:00    -8.1  ...     101.09          Snow
# 8770  12/31/2012 10:00    -7.4  ...     101.05      Snow,Fog
# 8772  12/31/2012 12:00    -5.8  ...     100.78          Snow
# 8773  12/31/2012 13:00    -4.6  ...     100.63          Snow
#
# [474 rows x 8 columns]

# %% [markdown]
# **FIND OUT ALL THE NULL VALUES IN THE DATA**

# %%
data.isnull()
# Out:
#       Date/Time  Temp_C  Dew Point Temp_C  ...  Visibility_km  Press_kPa  Weather
# 0         False   False             False  ...          False      False    False
# 1         False   False             False  ...          False      False    False
# 2         False   False             False  ...          False      False    False
# 3         False   False             False  ...          False      False    False
# 4         False   False             False  ...          False      False    False
# ...         ...     ...               ...  ...            ...        ...      ...
# 8779      False   False             False  ...          False      False    False
# 8780      False   False             False  ...          False      False    False
# 8781      False   False             False  ...          False      False    False
# 8782      False   False             False  ...          False      False    False
# ...

# %%
#another method to find null values
data.isnull().sum()
# Out:
# Date/Time           0
# Temp_C              0
# Dew Point Temp_C    0
# Rel Hum_%           0
# Wind Speed_km/h     0
# Visibility_km       0
# Press_kPa           0
# Weather             0
# dtype: int64

# %%
data.notnull().sum()
# Out:
# Date/Time           8784
# Temp_C              8784
# Dew Point Temp_C    8784
# Rel Hum_%           8784
# Wind Speed_km/h     8784
# Visibility_km       8784
# Press_kPa           8784
# Weather             8784
# dtype: int64

# %% [markdown]
# **RENAME THE COLUMN NAME "Weather" of the dataframe to "Weather Condition".**

# %%
data.head(2)
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  ...  Visibility_km  Press_kPa  Weather
# 0  1/1/2012 0:00    -1.8              -3.9  ...            8.0     101.24      Fog
# 1  1/1/2012 1:00    -1.8              -3.7  ...            8.0     101.24      Fog
#
# [2 rows x 8 columns]

# %%
data.rename(columns = {'Weather' : 'Weather Condition'}) #only for this the name changes.
# Out:
#              Date/Time  Temp_C  ...  Press_kPa     Weather Condition
# 0        1/1/2012 0:00    -1.8  ...     101.24                   Fog
# 1        1/1/2012 1:00    -1.8  ...     101.24                   Fog
# 2        1/1/2012 2:00    -1.8  ...     101.26  Freezing Drizzle,Fog
# 3        1/1/2012 3:00    -1.5  ...     101.27  Freezing Drizzle,Fog
# 4        1/1/2012 4:00    -1.5  ...     101.23                   Fog
# ...                ...     ...  ...        ...                   ...
# 8779  12/31/2012 19:00     0.1  ...     100.13                  Snow
# 8780  12/31/2012 20:00     0.2  ...     100.03                  Snow
# 8781  12/31/2012 21:00    -0.5  ...      99.95                  Snow
# 8782  12/31/2012 22:00    -0.2  ...      99.91                  Snow
# 8783  12/31/2012 23:00     0.0  ...      99.89                  Snow
#
# [8784 rows x 8 columns]

# %%
#To change the name in the data permanently.
data.rename(columns = {'Weather' : 'Weather Condition'}, inplace = True)

# %% [markdown]
# **WHAT IS THE MEAN "Visibility"**

# %%
data.head(2)
# Out:
#        Date/Time  Temp_C  ...  Press_kPa  Weather Condition
# 0  1/1/2012 0:00    -1.8  ...     101.24                Fog
# 1  1/1/2012 1:00    -1.8  ...     101.24                Fog
#
# [2 rows x 8 columns]

# %%
data.Visibility_km.mean()
# Out:
# 27.66444672131151

# %% [markdown]
# **WHAT IS THE Standard Deviation of "Pressure" in the data?**

# %%
data.Press_kPa.std()
# Out:
# 0.8440047459486474

# %% [markdown]
# **What is the Varience of "Relative Humidity" in this data ?**

# %%
data['Rel Hum_%'].var()
# Out:
# 286.2485501984998

# %% [markdown]
# **Find all instances when "Snow" was recorded.**

# %%
#value_counts()
#data.head(2)
data['Weather Condition'].value_counts()
# Out:
# Mainly Clear                               2106
# Mostly Cloudy                              2069
# Cloudy                                     1728
# Clear                                      1326
# Snow                                        390
# Rain                                        306
# Rain Showers                                188
# Fog                                         150
# Rain,Fog                                    116
# Drizzle,Fog                                  80
# Snow Showers                                 60
# Drizzle                                      41
# Snow,Fog                                     37
# Snow,Blowing Snow                            19
# Rain,Snow                                    18
# Thunderstorms,Rain Showers                   16
# Haze                                         16
# Drizzle,Snow,Fog                             15
# Freezing Rain                                14
# Freezing Drizzle,Snow                        11
# ...

# %%
#filtering
data[data['Weather Condition'] == 'Snow'].tail(50)
# Out:
#              Date/Time  Temp_C  ...  Press_kPa  Weather Condition
# 8496   12/20/2012 0:00     0.4  ...     101.57               Snow
# 8502   12/20/2012 6:00    -1.6  ...     101.82               Snow
# 8507  12/20/2012 11:00    -1.1  ...     101.92               Snow
# 8530  12/21/2012 10:00     1.0  ...      99.24               Snow
# 8531  12/21/2012 11:00     0.9  ...      99.01               Snow
# 8532  12/21/2012 12:00     1.3  ...      98.67               Snow
# 8533  12/21/2012 13:00     1.8  ...      98.36               Snow
# 8542  12/21/2012 22:00     0.7  ...      97.75               Snow
# 8548   12/22/2012 4:00     0.6  ...      97.98               Snow
# 8549   12/22/2012 5:00    -0.9  ...      98.07               Snow
# 8550   12/22/2012 6:00    -1.6  ...      98.19               Snow
# 8551   12/22/2012 7:00    -2.2  ...      98.32               Snow
# 8552   12/22/2012 8:00    -2.5  ...      98.44               Snow
# ...

# %%
#str.contains
data[data['Weather Condition'].str.contains('Snow')]
# Out:
#              Date/Time  Temp_C  ...  Press_kPa  Weather Condition
# 41      1/2/2012 17:00    -2.1  ...      99.66       Snow Showers
# 44      1/2/2012 20:00    -5.6  ...     100.07       Snow Showers
# 45      1/2/2012 21:00    -5.8  ...     100.15       Snow Showers
# 47      1/2/2012 23:00    -7.4  ...     100.27       Snow Showers
# 48       1/3/2012 0:00    -9.0  ...     100.35       Snow Showers
# ...                ...     ...  ...        ...                ...
# 8779  12/31/2012 19:00     0.1  ...     100.13               Snow
# 8780  12/31/2012 20:00     0.2  ...     100.03               Snow
# 8781  12/31/2012 21:00    -0.5  ...      99.95               Snow
# 8782  12/31/2012 22:00    -0.2  ...      99.91               Snow
# 8783  12/31/2012 23:00     0.0  ...      99.89               Snow
#
# [583 rows x 8 columns]

# %% [markdown]
# **Find  all instances when 'Wind Speed is above 24' and 'Visibility' is 25'.**

# %%
data.head(2)
# Out:
#        Date/Time  Temp_C  ...  Press_kPa  Weather Condition
# 0  1/1/2012 0:00    -1.8  ...     101.24                Fog
# 1  1/1/2012 1:00    -1.8  ...     101.24                Fog
#
# [2 rows x 8 columns]

# %%
data[(data['Wind Speed_km/h'] > 24) & (data['Visibility_km'] == 25)]
# Out:
#              Date/Time  Temp_C  ...  Press_kPa  Weather Condition
# 23      1/1/2012 23:00     5.3  ...      99.31             Cloudy
# 24       1/2/2012 0:00     5.2  ...      99.26       Rain Showers
# 25       1/2/2012 1:00     4.6  ...      99.26             Cloudy
# 26       1/2/2012 2:00     3.9  ...      99.26      Mostly Cloudy
# 27       1/2/2012 3:00     3.7  ...      99.30      Mostly Cloudy
# ...                ...     ...  ...        ...                ...
# 8705  12/28/2012 17:00    -8.6  ...     101.34       Mainly Clear
# 8753  12/30/2012 17:00   -12.1  ...     101.26       Mainly Clear
# 8755  12/30/2012 19:00   -13.4  ...     101.47       Mainly Clear
# 8759  12/30/2012 23:00   -12.1  ...     101.52      Mostly Cloudy
# 8760   12/31/2012 0:00   -11.1  ...     101.51             Cloudy
#
# [308 rows x 8 columns]

# %% [markdown]
# **What is the mean value of each column against each 'Weather Condition'?**

# %%
data.head(2)
# Out:
#        Date/Time  Temp_C  ...  Press_kPa  Weather Condition
# 0  1/1/2012 0:00    -1.8  ...     101.24                Fog
# 1  1/1/2012 1:00    -1.8  ...     101.24                Fog
#
# [2 rows x 8 columns]

# %%
data.groupby('Weather Condition').mean()
# Out:
#                                             Temp_C  ...   Press_kPa
# Weather Condition                                   ...
# Clear                                     6.825716  ...  101.587443
# Cloudy                                    7.970544  ...  100.911441
# Drizzle                                   7.353659  ...  100.435366
# Drizzle,Fog                               8.067500  ...  100.786625
# Drizzle,Ice Pellets,Fog                   0.400000  ...  100.790000
# Drizzle,Snow                              1.050000  ...  100.890000
# Drizzle,Snow,Fog                          0.693333  ...   99.281333
# Fog                                       4.303333  ...  101.184067
# Freezing Drizzle                         -5.657143  ...  100.202857
# Freezing Drizzle,Fog                     -2.533333  ...  100.441667
# Freezing Drizzle,Haze                    -5.433333  ...  100.316667
# Freezing Drizzle,Snow                    -5.109091  ...  100.520909
# ...

# %% [markdown]
# **What is the Minimum & Maximum value of each column against each "Weather Condition"?**

# %%
data.head(2)
# Out:
#        Date/Time  Temp_C  ...  Press_kPa  Weather Condition
# 0  1/1/2012 0:00    -1.8  ...     101.24                Fog
# 1  1/1/2012 1:00    -1.8  ...     101.24                Fog
#
# [2 rows x 8 columns]

# %%
data.groupby('Weather Condition').min()
# Out:
#                                                 Date/Time  ...  Press_kPa
# Weather Condition                                          ...
# Clear                                      1/11/2012 1:00  ...      99.52
# Cloudy                                     1/1/2012 17:00  ...      98.39
# Drizzle                                   1/23/2012 21:00  ...      97.84
# Drizzle,Fog                               1/23/2012 20:00  ...      98.65
# Drizzle,Ice Pellets,Fog                   12/17/2012 9:00  ...     100.79
# Drizzle,Snow                             12/17/2012 15:00  ...     100.63
# Drizzle,Snow,Fog                         12/18/2012 21:00  ...      97.79
# Fog                                         1/1/2012 0:00  ...      98.31
# Freezing Drizzle                          1/13/2012 10:00  ...      98.44
# Freezing Drizzle,Fog                        1/1/2012 2:00  ...      98.74
# Freezing Drizzle,Haze                      2/1/2012 11:00  ...     100.28
# ...

# %%
data.groupby('Weather Condition').max()
# Out:
#                                                 Date/Time  ...  Press_kPa
# Weather Condition                                          ...
# Clear                                       9/9/2012 5:00  ...     103.63
# Cloudy                                     9/9/2012 23:00  ...     103.65
# Drizzle                                    9/30/2012 3:00  ...     101.56
# Drizzle,Fog                                9/30/2012 2:00  ...     102.07
# Drizzle,Ice Pellets,Fog                   12/17/2012 9:00  ...     100.79
# Drizzle,Snow                             12/19/2012 18:00  ...     101.15
# Drizzle,Snow,Fog                          12/22/2012 3:00  ...     100.15
# Fog                                        9/22/2012 0:00  ...     103.04
# Freezing Drizzle                            2/1/2012 5:00  ...     101.02
# Freezing Drizzle,Fog                      12/10/2012 5:00  ...     101.27
# Freezing Drizzle,Haze                      2/1/2012 13:00  ...     100.36
# ...

# %% [markdown]
# **Show all the Records where Weather Condition is Fog.**

# %%
data[data['Weather Condition'] == 'Fog']
# Out:
#              Date/Time  Temp_C  ...  Press_kPa  Weather Condition
# 0        1/1/2012 0:00    -1.8  ...     101.24                Fog
# 1        1/1/2012 1:00    -1.8  ...     101.24                Fog
# 4        1/1/2012 4:00    -1.5  ...     101.23                Fog
# 5        1/1/2012 5:00    -1.4  ...     101.27                Fog
# 6        1/1/2012 6:00    -1.5  ...     101.29                Fog
# ...                ...     ...  ...        ...                ...
# 8716   12/29/2012 4:00   -16.0  ...     101.25                Fog
# 8717   12/29/2012 5:00   -14.8  ...     101.25                Fog
# 8718   12/29/2012 6:00   -13.8  ...     101.25                Fog
# 8719   12/29/2012 7:00   -14.8  ...     101.22                Fog
# 8722  12/29/2012 10:00   -12.0  ...     101.15                Fog
#
# [150 rows x 8 columns]

# %% [markdown]
# **Find all instances when "Weather is Clear" or "Visibility is above 40".**

# %%
data[(data['Weather Condition'] == 'Clear') | (data['Visibility_km'] > 40)]
# Out:
#              Date/Time  Temp_C  ...  Press_kPa  Weather Condition
# 67      1/3/2012 19:00   -16.9  ...     101.74              Clear
# 106     1/5/2012 10:00    -6.0  ...     100.45       Mainly Clear
# 107     1/5/2012 11:00    -5.6  ...     100.41       Mainly Clear
# 108     1/5/2012 12:00    -4.7  ...     100.38       Mainly Clear
# 109     1/5/2012 13:00    -4.4  ...     100.40       Mainly Clear
# ...                ...     ...  ...        ...                ...
# 8749  12/30/2012 13:00   -12.4  ...     100.92      Mostly Cloudy
# 8750  12/30/2012 14:00   -11.8  ...     100.96       Mainly Clear
# 8751  12/30/2012 15:00   -11.3  ...     101.05       Mainly Clear
# 8752  12/30/2012 16:00   -11.4  ...     101.15       Mainly Clear
# 8756  12/30/2012 20:00   -13.8  ...     101.52              Clear
#
# [3027 rows x 8 columns]

# %% [markdown]
# **Find all instances when:
# A."Weather is Clear" and "Relative Humidity is greater than 50"
# or
# B. "Visibility is above 40"**

# %%
data.head(2)
# Out:
#        Date/Time  Temp_C  ...  Press_kPa  Weather Condition
# 0  1/1/2012 0:00    -1.8  ...     101.24                Fog
# 1  1/1/2012 1:00    -1.8  ...     101.24                Fog
#
# [2 rows x 8 columns]

# %%
data[(data['Weather Condition'] == 'Clear') & (data['Rel Hum_%'] > 50) | (data['Visibility_km'] > 40)]
# Out:
#              Date/Time  Temp_C  ...  Press_kPa  Weather Condition
# 106     1/5/2012 10:00    -6.0  ...     100.45       Mainly Clear
# 107     1/5/2012 11:00    -5.6  ...     100.41       Mainly Clear
# 108     1/5/2012 12:00    -4.7  ...     100.38       Mainly Clear
# 109     1/5/2012 13:00    -4.4  ...     100.40       Mainly Clear
# 110     1/5/2012 14:00    -5.1  ...     100.46       Mainly Clear
# ...                ...     ...  ...        ...                ...
# 8749  12/30/2012 13:00   -12.4  ...     100.92      Mostly Cloudy
# 8750  12/30/2012 14:00   -11.8  ...     100.96       Mainly Clear
# 8751  12/30/2012 15:00   -11.3  ...     101.05       Mainly Clear
# 8752  12/30/2012 16:00   -11.4  ...     101.15       Mainly Clear
# 8756  12/30/2012 20:00   -13.8  ...     101.52              Clear
#
# [2921 rows x 8 columns]

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(data['Wind Speed_km/h'])

# %%
plt.plot(data['Wind Speed_km/h'], color = 'green')
plt.xlabel("Record Number")
plt.ylabel("Wind Speed_km/h")
plt.title("Graph to analysis WINDSPEED")
plt.show()

# %%
plt.plot(data['Wind Speed_km/h'],marker='o', markerfacecolor='Blue', markersize=5,color='green',linewidth=5,linestyle='dashed')

# %%
data.groupby('Weather Condition')['Visibility_km'].count()
# Out:
# Weather Condition
# Clear                                      1326
# Cloudy                                     1728
# Drizzle                                      41
# Drizzle,Fog                                  80
# Drizzle,Ice Pellets,Fog                       1
# Drizzle,Snow                                  2
# Drizzle,Snow,Fog                             15
# Fog                                         150
# Freezing Drizzle                              7
# Freezing Drizzle,Fog                          6
# Freezing Drizzle,Haze                         3
# Freezing Drizzle,Snow                        11
# Freezing Fog                                  4
# Freezing Rain                                14
# Freezing Rain,Fog                             4
# Freezing Rain,Haze                            2
# Freezing Rain,Ice Pellets,Fog                 1
# Freezing Rain,Snow Grains                     1
# Haze                                         16
# ...

# %%
plt.scatter(x = data['Temp_C'], y = data['Wind Speed_km/h'], color = 'red')
plt.xlabel("temperature")
plt.ylabel("windspeed")
plt.title("Temperature vs WindSpeed")
plt.show()

# %%
plt.boxplot(data['Press_kPa'])
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7f853b640490>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f853b6407d0>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7f853b646810>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7f853b6462d0>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f853b640810>,
#   <matplotlib.lines.Line2D at 0x7f853b640790>]}
